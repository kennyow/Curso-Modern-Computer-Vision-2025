# %% [markdown]
# <div style="border: 2px solid #00ffea; background: linear-gradient(135deg, #0a0a2a, #1a1a4a); padding: 16px; color: #00ffea; font-size: 42px; font-family: 'Courier New', monospace; text-shadow: 0 0 10px #00ffea; letter-spacing: 2px; border-radius: 8px;">
# <b> IMAGE OPERATIONS - OpenCV Lesson</b>
# </div>

# %% [markdown]
# # **Getting Started**
#
# 1. Import the OpenCV Model in Python
# 2. Load Images
# 3. Display Images
# 4. Save Images
# 5. Getting the Image Dimensions

# %%
# import OpenCV
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %% [markdown]
# ## **Dowloading Images - Not Working**

# %%
# import requests
# import zipfile

# url = "https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip"
# filename = "images.zip"

# r = requests.get(url, stream=True)
# r.raise_for_status()  # falha explícita se der erro

# with open(filename, "wb") as f:
#     for chunk in r.iter_content(chunk_size=8192):
#         f.write(chunk)

# print("Download concluído")

# with zipfile.ZipFile(filename, "r") as zip_ref:
#     zip_ref.extractall("images")

# print("Extração concluída")

# %%
# Load an image using 'imread' specifying the path to image
image = cv2.imread('./images/flowers.jpeg')

# %% [markdown]
# ## Display Images

# %%
from matplotlib import pyplot as plt

#Show the image with matplotlib
#Let's create a simple function to make displaying our images simpler and easier
def imshow(title = "", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.title(title)
    plt.show()

# %%
# Let's test it out
imshow("Displaying Our First Image", image)

# %% [markdown]
# ## Saving Images

# %%
# Simply use 'imwrite' specificing the file name and the image to be saved
cv2.imwrite('outputa.jpg', image)

# or .png
#cv2.imwrite('output.png', image)
# Out:
# True

# %% [markdown]
# ## Display Image Dimensions ( Height, Width, Depth)

# %%
from IPython.display import Image, display
display(Image(filename="ilustrations/array.png"))

# %%
import numpy as np

# The flower's image
print(image.shape)
# Out:
# (960, 1280, 3)

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 960 pixels
# Width of Image: 1280 pixels
# Depth of Image: 3 colors components
